# %% [markdown]
# <a href="https://colab.research.google.com/github/briskicedteaa/Scientific-Visualization-for-Computational-Biology/blob/main/PCA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
import pandas as pd
from sklearn.decomposition import PCA

# %%
df = pd.read_csv('/content/Ligands2.csv', sep =';' )
df = df.drop(columns=df.columns.difference(['Ligand Efficiency LE', 'Ligand Efficiency LLE', 'Ligand Efficiency BEI', 'Ligand Efficiency SEI', 'Molecular Weight', 'Standard Value', 'AlogP']))
df = df.dropna()
df
# Out:
#        Molecular Weight  AlogP  Standard Value  Ligand Efficiency BEI  \
# 0                472.67   4.21           60.00                  15.28
# 8                323.39   3.29          657.00                  19.12
# 9                413.52   5.25        22300.00                  11.25
# 10               379.50   4.36            7.00                  21.49
# 13               427.55   3.69          280.00                  15.33
# ...                 ...    ...             ...                    ...
# 20124            351.35   3.88         1670.00                  16.44
# 20125            433.49   7.26            7.10                  18.80
# 20126            471.59   8.33           70.00                  15.17
# 20128            539.81   7.45            7.63                  15.04
# 20131            455.41   5.43          308.90                  14.30
#
#        Ligand Efficiency LE  Ligand Efficiency LLE  Ligand Efficiency SEI
# ...

# %%
fig = plt.figure(1, figsize=(8, 6))
ax = fig.add_subplot(111)

pca_model = PCA(n_components=2)
X_reduced = pca_model.fit_transform(df)
scatter = ax.scatter(
    X_reduced[:, 0],
    X_reduced[:, 1],
    s=40,
)

ax.set(
    title="PCA For Acetylcholinterase Dataset",
    xlabel="PC1",
    ylabel="PC2"
)
ax.xaxis.set_ticklabels([])
ax.yaxis.set_ticklabels([])

PC1 = X_reduced[:, 0]
PC2 = X_reduced[:, 1]

df['PC1'] = PC1
df['PC2'] = PC2

df.to_csv('Ligands2_with_PCA.csv', index=False)

display(df.head())
plt.show()
# Out:
#     Molecular Weight  AlogP  Standard Value  Ligand Efficiency BEI  \
# 0             472.67   4.21            60.0                  15.28
# 8             323.39   3.29           657.0                  19.12
# 9             413.52   5.25         22300.0                  11.25
# 10            379.50   4.36             7.0                  21.49
# 13            427.55   3.69           280.0                  15.33
#
#     Ligand Efficiency LE  Ligand Efficiency LLE  Ligand Efficiency SEI  \
# 0                   0.29                   3.01                  12.61
# 8                   0.35                   2.89                  15.95
# 9                   0.20                  -0.60                  12.00
# 10                  0.40                   3.79                  21.03
# 13                  0.28                   2.86                   6.84
#
#              PC1         PC2
# 0  -18478.225644  141.902225
# 8  -17015.726807 -223.315089
# 9   35998.483653   20.468102
# ...

# %%
print('Explained variance ratio per principal component:')
display(pca_model.explained_variance_ratio_)
# Out:
# Explained variance ratio per principal component:
# array([9.99939282e-01, 6.05982913e-05])
