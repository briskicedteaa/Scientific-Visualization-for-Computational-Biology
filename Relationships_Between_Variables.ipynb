# %% [markdown]
# <a href="https://colab.research.google.com/github/briskicedteaa/Scientific-Visualization-for-Computational-Biology/blob/main/Relationships_Between_Variables.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
import pandas as pd

# %%
df = pd.read_csv('/content/Ligands1.csv', sep =';' )
df = df.drop(columns=df.columns.difference(['Ligand Efficiency LE', 'Ligand Efficiency LLE', 'Ligand Efficiency BEI', 'Ligand Efficiency SEI', 'Molecular Weight']))
df = df.dropna()
df
# Out:
#        Molecular Weight  Ligand Efficiency BEI  Ligand Efficiency LE  \
# 0                472.67                  15.28                  0.29
# 8                323.39                  19.12                  0.35
# 9                413.52                  11.25                  0.20
# 10               379.50                  21.49                  0.40
# 13               427.55                  15.33                  0.28
# ...                 ...                    ...                   ...
# 20124            351.35                  16.44                  0.33
# 20125            433.49                  18.80                  0.36
# 20126            471.59                  15.17                  0.30
# 20128            539.81                  15.04                  0.30
# 20131            455.41                  14.30                  0.32
#
#        Ligand Efficiency LLE  Ligand Efficiency SEI
# 0                       3.01                  12.61
# ...

# %%
sns.pairplot(df)
