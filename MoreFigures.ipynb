# %% [markdown]
# <a href="https://colab.research.google.com/github/briskicedteaa/Scientific-Visualization-for-Computational-Biology/blob/main/MoreFigures.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import plotly.express as px
import pandas as pd
