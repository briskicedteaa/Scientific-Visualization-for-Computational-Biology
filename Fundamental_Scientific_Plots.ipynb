# %% [markdown]
# <a href="https://colab.research.google.com/github/briskicedteaa/Scientific-Visualization-for-Computational-Biology/blob/main/Fundamental_Scientific_Plots.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
import pandas as pd

# %%
df = pd.read_csv('/content/Ligands.csv', sep =';' )
df = df.drop(columns=df.columns.difference(['Ligand Efficiency LE', 'Ligand Efficiency LLE']))
df = df.dropna()
df
# Out:
#        Ligand Efficiency LE  Ligand Efficiency LLE
# 0                      0.29                   3.01
# 8                      0.35                   2.89
# 9                      0.20                  -0.60
# 10                     0.40                   3.79
# 13                     0.28                   2.86
# ...                     ...                    ...
# 20124                  0.33                   1.90
# 20125                  0.36                   0.89
# 20126                  0.30                  -1.18
# 20128                  0.30                   0.67
# 20131                  0.32                   1.08
#
# [8019 rows x 2 columns]

# %%
sns.set_theme()
sns.displot(df, x="Ligand Efficiency LE")

# %%
g = sns.relplot(data= df, x="Ligand Efficiency LLE", y="Ligand Efficiency LE")
g.ax.axline(xy1=(10, 2), slope=.2, color="b", dashes=(5, 2))

# %%
sns.set_theme(style="darkgrid")

sns.relplot(data= df, x="Ligand Efficiency LLE", y="Ligand Efficiency LE", kind="line")
